# %% [markdown]
# # 00 — Data audit
#
# This notebook will document schema inspection and data-quality checks without selecting a business problem. Reusable or result-critical logic must be implemented in `src/ecommerce_product_analytics/`; derived datasets must be written only to `data/interim/` or `data/processed/`.
