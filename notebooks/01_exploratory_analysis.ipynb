# %% [markdown]
# # 01 — Exploratory analysis
#
# Exploratory analysis will begin only after the initial data audit is complete and the user has made the analytical decisions required by `AGENTS.md`. This notebook currently contains no calculations, findings, or hypotheses.
